# %%
###  Analyse Statistique de Base

## 1. Statistiques Descriptives

import numpy as np

data = [1, 2, 2, 3, 3, 3, 4, 4, 5, 5, 6]
mean = np.mean(data)
median = np.median(data)
std_dev = np.std(data)

print(f"Moyenne: {mean}, Médiane: {median}, Écart-type: {std_dev}")
# Out:
# Moyenne: 3.4545454545454546, Médiane: 3.0, Écart-type: 1.4373989364401722

# %%
# Histogramme de distribution
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data, kde=True)
plt.title('Distribution des Données')
plt.show()

# %%
# Diagramme à boîte
sns.boxplot(data=data)
plt.title('Diagramme à Boîte des Données')
plt.show()

# %%
from scipy.stats import ttest_ind

# Comparer deux échantillons
sample1 = [1, 2, 3, 4, 5]
sample2 = [1, 2, 3, 4, 6]
t_stat, p_value = ttest_ind(sample1, sample2)

print(f"Statistique t: {t_stat}, Valeur p: {p_value}")
# Out:
# Statistique t: -0.17960530202677505, Valeur p: 0.8619282156106918
